# %% [markdown]
# # I like taking my data science notes in Obsidian and You will love it too...

# %%
print("Welcome to this amazing world of knowledge...")
# Out:
# Welcome to this amazing world of knowledge...
